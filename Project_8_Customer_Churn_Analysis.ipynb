# %%
#Importing necessery libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Libraries Imported

# %%
#Importing Dataset
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# Dataset Imported

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# As we see there is no null value present in the dataset

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# Columns names

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# As we see There are 7034 rows and 21 columns present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# As we can see there are all types of data is preseent , some of the columns have object , some of the ccolumns havee int and some have float and Our target variable have object data type and we have classes in it so we can say it is a classification problem

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# There are only 3 numerical data columns

# %%
sns.countplot(df['Churn'])
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# This is our target column and we can see we there are difference between No and Yes and it means there is class imbalancing problem

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
sns.countplot(df['Partner'])
plt.subplot(1,3,2)
sns.countplot(df['Dependents'])
plt.subplot(1,3,3)
sns.countplot(df['PhoneService'])

# %% [markdown]
# There are nearby same values in partner column

# %% [markdown]
# More no of people are not dependent
#
# More no of people have phone service and nearby 10% people didn't have phone service

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
sns.countplot(df['MultipleLines'])
plt.subplot(1,3,2)
sns.countplot(df['InternetService'])
plt.subplot(1,3,3)
sns.countplot(df['OnlineSecurity'])

# %% [markdown]
# Some people have Multiple Lines and Some didn't have Multiple Lines
#
# Some of them use DSL internet service and some use Fiber Optic, Users of Fiber optic are more and some didn't have internet service
#
# More no of people dose not have online security , there are very less people have have online security

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
sns.countplot(df['OnlineBackup'])
plt.subplot(1,3,2)
sns.countplot(df['DeviceProtection'])
plt.subplot(1,3,3)
sns.countplot(df['TechSupport'])

# %% [markdown]
# More no of people doesn't have online backup , device protection and tech support and the people with no internet services are in the No category , There are very few people haev the all three things

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
sns.countplot(df['StreamingTV'])
plt.subplot(1,3,2)
sns.countplot(df['StreamingMovies'])
plt.subplot(1,3,3)
sns.countplot(df['PaperlessBilling'])

# %% [markdown]
# The Streming TV and Movies have nearby same numbers still More people with NO Tv Streaming and Movies
#
# More no of people haev PaperlessBilling

# %%
plt.xticks(rotation = 45)
sns.countplot(df['PaymentMethod'])

# %% [markdown]
# More no of people use Electronic Check method for payment and some of them Mailed the check, some usee Bank transfer method and Some pays through the Credit Card

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'Churn', y='MonthlyCharges', data = df)

# %% [markdown]
# No major difference in monthly charges with the churn

# %%
sns.catplot(data = df,x = 'Churn',
           kind = 'count',col = 'PaymentMethod')

# %% [markdown]
# From the above observation we can see that People who use Electronic check as payment method have more of Yes and people who use Mailed Check , Bank Trasfer and Credit card as payment method have less churn

# %%
sns.catplot(data = df,x = 'Churn',
           kind = 'count',col = 'PaperlessBilling')

# %% [markdown]
# People who use papaerless billing have more no churn than the people who use paper billing

# %%
sns.catplot(data = df,x = 'Churn',
           kind = 'count',col = 'Contract')

# %% [markdown]
# From the above observation we can say that customers who have Two year contract have less churn numbers and Who have Month to month contract have moreno of churn

# %%
sns.catplot(data = df,x = 'Churn',
           kind = 'count',col = 'DeviceProtection')

# %% [markdown]
# The customers with no internet services and have device protection have more no. of churn resp.

# %%
plt.figure(figsize=(5,5))
sns.violinplot(data =df ,x ='gender',y ='MonthlyCharges',hue= 'Churn',split =True)

# %% [markdown]
# The customers who has 70 to 100 Monthly charge have more no. of churn and the customers with 15 - 30 monthly charge have less no.of churn

# %%
plt.figure(figsize=(5,5))
sns.violinplot(data =df ,x ='gender',y ='tenure',hue= 'Churn',split =True)

# %% [markdown]
# The customers with the tenure upto 20 have more no. of churn

# %%
#Cut the alphabets from the customer id
df['customerID'] = df['customerID'].apply(lambda x: x[0:4])

# %%
#Convert the customer id type from object to int
df['customerID'] = df['customerID'].astype(int)

# %%
cat_df=df.select_dtypes(include='object')
cat_df.columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# All categorical columns

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report
from sklearn.metrics import plot_roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
#encoding the categorical data
le = LabelEncoder()
for i in cat_df:
    df[i] = le.fit_transform(df[i])
df
# Out:
#       customerID  gender  SeniorCitizen  ...  MonthlyCharges  TotalCharges  Churn
# 0           7590       0              0  ...           29.85          2505      0
# 1           5575       1              0  ...           56.95          1466      0
# 2           3668       1              0  ...           53.85           157      1
# 3           7795       1              0  ...           42.30          1400      0
# 4           9237       0              0  ...           70.70           925      1
# ...          ...     ...            ...  ...             ...           ...    ...
# 7038        6840       1              0  ...           84.80          1597      0
# 7039        2234       0              0  ...          103.20          5698      0
# 7040        4801       0              0  ...           29.60          2994      0
# 7041        8361       1              1  ...           74.40          2660      1
# ...

# %% [markdown]
# Encode the categorical columns by LabelEncoder

# %%
sns.pairplot(df,hue = 'Churn')

# %%
plt.figure(figsize = (20,26))
plotnumber = 1

for column in df:
    if plotnumber <= 21:
        ax = plt.subplot(7,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
    plotnumber += 1
plt.show()

# %% [markdown]
# From the above observation we can see most of the columns have categorical data and only two columns have numerical data Monthly charges and Total Charges , and both are Normally distributed

# %%
plt.figure(figsize = (20,26))
graph = 1

for column in df:
    if graph <= 21:
        ax = plt.subplot(7,3,graph)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize = 20)
    graph += 1
plt.show()

# %% [markdown]
# From the above observation we can see most of the columns have categorical data and only two columns have numerical data Monthly charges and Total Charges, and They dont have outliers

# %%
df_corr = df.corr().abs()
df_corr
# Out:
#                   customerID    gender  ...  TotalCharges     Churn
# customerID          1.000000  0.006073  ...      0.003144  0.017385
# gender              0.006073  1.000000  ...      0.005291  0.008612
# SeniorCitizen       0.002197  0.001874  ...      0.037653  0.150889
# Partner             0.026779  0.001808  ...      0.059568  0.150448
# Dependents          0.012816  0.010517  ...      0.009572  0.164221
# tenure              0.007805  0.005106  ...      0.158523  0.352229
# PhoneService        0.006252  0.006488  ...      0.083195  0.011942
# MultipleLines       0.004366  0.006739  ...      0.114955  0.038037
# InternetService     0.012230  0.000863  ...      0.055724  0.047291
# OnlineSecurity      0.013174  0.015017  ...      0.042357  0.289309
# OnlineBackup        0.003351  0.012057  ...      0.090756  0.195525
# DeviceProtection    0.007084  0.000549  ...      0.105905  0.178134
# TechSupport         0.001106  0.006825  ...      0.057488  0.282492
# ...

# %% [markdown]
# Corelation of the column with each other

# %%
plt.figure(figsize =(20,20))
sns.heatmap(df_corr, annot = True, square = True,
           linewidth =1,fmt ='.1g',cmap = 'binary')

# %% [markdown]
# From the above observation we can say that the corelation between the columns with each other is less

# %%
df.skew()
# Out:
# customerID          0.006830
# gender             -0.019031
# SeniorCitizen       1.833633
# Partner             0.067922
# Dependents          0.875199
# tenure              0.239540
# PhoneService       -2.727153
# MultipleLines       0.118719
# InternetService     0.205423
# OnlineSecurity      0.416985
# OnlineBackup        0.182930
# DeviceProtection    0.186847
# TechSupport         0.402365
# StreamingTV         0.028486
# StreamingMovies     0.014657
# Contract            0.630959
# PaperlessBilling   -0.375396
# PaymentMethod      -0.170129
# MonthlyCharges     -0.220524
# TotalCharges        0.015857
# Churn               1.063031
# dtype: float64

# %% [markdown]
# As we can see the skewness of the data, some of the column have skewness but these are categorical column and the others with numerical ones dosen't have skewness

# %%
#Splitting the data
x = df.drop('Churn',axis = 1)
y = df['Churn']

# %% [markdown]
# Seprating the feature and target variable

# %%
y.value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# As we see above there is imbalancing problem so now we have to cure it

# %%
#Resampling the data
SM = SMOTE()
x,y = SM.fit_resample(x,y)

# %%
sns.countplot(y)

# %% [markdown]
# As wee can see after the resampling both have equal data

# %%
#Scaling the data
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# Scaling the data by using standard scaler method

# %%
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train, x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.25,random_state = i)
    log_reg = LogisticRegression()
    log_reg.fit(x_train, y_train)
    pred = log_reg.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
print('Best Accuracy is',maxAccu, 'on Random State',maxRS)
# Out:
# Best Accuracy is 0.793196752995748 on Random State 124

# %% [markdown]
# From above code we get best random state 124

# %%
x_train ,x_test, y_train, y_test = train_test_split(x_scaled,y,test_size = 0.25,random_state = maxRS)

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
predlr = log_reg.predict(x_test)
LRC = accuracy_score(y_test,predlr)
print('Accuracy_Score :',LRC)
print('Confusion_Matrix:\n',confusion_matrix(y_test,predlr))
print('Classification_Report:\n',classification_report(y_test,predlr))
print('Roc_Auc Score:',roc_auc_score(y_test,predlr))

metrics.plot_roc_curve(log_reg, x_test, y_test)  
plt.show()
# Out:
# Accuracy_Score : 0.793196752995748
# Confusion_Matrix:
#  [[ 950  296]
#  [ 239 1102]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78      1246
#            1       0.79      0.82      0.80      1341
#
#     accuracy                           0.79      2587
#    macro avg       0.79      0.79      0.79      2587
# weighted avg       0.79      0.79      0.79      2587
#
# Roc_Auc Score: 0.7921073011563926

# %% [markdown]
# By applying LogisticRegression in Result we get 79.31 Acc Score

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
preddt = dt.predict(x_test)
DTC = accuracy_score(y_test,preddt)
print('Accuracy_Score :',DTC)
print('Confusion_Matrix:\n',confusion_matrix(y_test,preddt))
print('Classification_Report:\n',classification_report(y_test,preddt))
print('Roc_Auc Score:',roc_auc_score(y_test,preddt))

metrics.plot_roc_curve(dt, x_test, y_test)  
plt.show()
# Out:
# Accuracy_Score : 0.8198685736374178
# Confusion_Matrix:
#  [[1018  228]
#  [ 238 1103]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81      1246
#            1       0.83      0.82      0.83      1341
#
#     accuracy                           0.82      2587
#    macro avg       0.82      0.82      0.82      2587
# weighted avg       0.82      0.82      0.82      2587
#
# Roc_Auc Score: 0.8197674766560975

# %% [markdown]
# By applying DecisionTreeClassifier in Result we get 81.98 Acc Score

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
predrf = rf.predict(x_test)
RFC = accuracy_score(y_test,predrf)
print('Accuracy_Score :',RFC)
print('Confusion_Matrix:\n',confusion_matrix(y_test,predrf))
print('Classification_Report:\n',classification_report(y_test,predrf))
print('Roc_Auc Score:',roc_auc_score(y_test,predrf))

metrics.plot_roc_curve(rf, x_test, y_test)  
plt.show()
# Out:
# Accuracy_Score : 0.8693467336683417
# Confusion_Matrix:
#  [[1125  121]
#  [ 217 1124]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1246
#            1       0.90      0.84      0.87      1341
#
#     accuracy                           0.87      2587
#    macro avg       0.87      0.87      0.87      2587
# weighted avg       0.87      0.87      0.87      2587
#
# Roc_Auc Score: 0.8705348539637054

# %% [markdown]
# By applying RandomForestClassifier in Result we get 86.93 Acc Score

# %%
from sklearn import svm
svc = svm.SVC()
svc.fit(x_train, y_train)
predsvc = svc.predict(x_test)
SVC = accuracy_score(y_test,predsvc)
print('Accuracy_Score :',SVC)
print('Confusion_Matrix:\n',confusion_matrix(y_test,predsvc))
print('Classification_Report:\n',classification_report(y_test,predsvc))
print('Roc_Auc Score:',roc_auc_score(y_test,predsvc))

metrics.plot_roc_curve(svc, x_test, y_test)  
plt.show()
# Out:
# Accuracy_Score : 0.8500193274062621
# Confusion_Matrix:
#  [[1068  178]
#  [ 210 1131]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1246
#            1       0.86      0.84      0.85      1341
#
#     accuracy                           0.85      2587
#    macro avg       0.85      0.85      0.85      2587
# weighted avg       0.85      0.85      0.85      2587
#
# Roc_Auc Score: 0.8502716522850752

# %% [markdown]
# By applying SVC in Result we get 85 Acc Score

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
predknn = knn.predict(x_test)
KNN = accuracy_score(y_test,predknn)
print('Accuracy_Score :',KNN)
print('Confusion_Matrix:\n',confusion_matrix(y_test,predknn))
print('Classification_Report:\n',classification_report(y_test,predknn))
print('Roc_Auc Score:',roc_auc_score(y_test,predknn))

metrics.plot_roc_curve(svc, x_test, y_test)  
plt.show()
# Out:
# Accuracy_Score : 0.7955160417471975
# Confusion_Matrix:
#  [[ 862  384]
#  [ 145 1196]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.69      0.77      1246
#            1       0.76      0.89      0.82      1341
#
#     accuracy                           0.80      2587
#    macro avg       0.81      0.79      0.79      2587
# weighted avg       0.80      0.80      0.79      2587
#
# Roc_Auc Score: 0.791842770841338

# %% [markdown]
# By applying KNeighborsClassifier in Result we get 79.55 Acc Score

# %%
#Calculating Cross_Val_score
LRCV = cross_val_score(log_reg, x, y, cv = 5)
print('Cross Validation score of LogisticRegression model:',LRCV.mean())
# Out:
# Cross Validation score of LogisticRegression model: 0.7725174709245989

# %%
DTCV = cross_val_score(dt, x, y, cv = 5)
print('Cross Validation score of DecisionTree model:',DTCV.mean())
# Out:
# Cross Validation score of DecisionTree model: 0.7974645736580719

# %%
RFCV = cross_val_score(rf,x,y,cv = 5)
print('Cross Validation score of RandomForest model:',RFCV.mean())
# Out:
# Cross Validation score of RandomForest model: 0.8375707651249289

# %%
SVCV = cross_val_score(svc,x,y,cv = 5)
print('Cross Validation score of SVC model:',SVCV.mean())
# Out:
# Cross Validation score of SVC model: 0.5229013526103067

# %%
KNNCV = cross_val_score(knn,x,y,cv = 5)
print('Cross Validation DScore of KNN model:',KNNCV.mean())
# Out:
# Cross Validation DScore of KNN model: 0.6823583004695493

# %%
#Creating DataFrame of Difference between acc_Score and CV score
pd.DataFrame({'Model':['Logistic Regression','RandomForestClassifier','DecisionTreeClassifier','SVC','KNeighborsClassifier'],
             'acc_score':[LRC,RFC,DTC,SVC,KNN],
             'cross_val_score':[LRCV.mean(),RFCV.mean(),DTCV.mean(),SVCV.mean(),KNNCV.mean()],
             'Difference':[(LRC-LRCV.mean()),(RFC-RFCV.mean()),(DTC-DTCV.mean()),(SVC-SVCV.mean()),(KNN-KNNCV.mean())]})
# Out:
#                     Model  acc_score  cross_val_score  Difference
# 0     Logistic Regression   0.793197         0.772517    0.020679
# 1  RandomForestClassifier   0.869347         0.837571    0.031776
# 2  DecisionTreeClassifier   0.819869         0.797465    0.022404
# 3                     SVC   0.850019         0.522901    0.327118
# 4    KNeighborsClassifier   0.795516         0.682358    0.113158

# %% [markdown]
# As we can see the DecisionTreeClassifier, LogisticRegression and RandomForestClassifier have less diff , So we use all 3 for GridSearchCV

# %%
#GridSearchCV Parameteers for DecisionTreeClassifier
#Adding parameters 
parameters = {'criterion' :['gini', 'entropy'],
              'max_features': ['auto', 'sqrt', 'log2'],
              'max_depth' : [4,5,6,7,8],
              'splitter' :['best', 'random']}

# %% [markdown]
# Parameters for DecisionTreeClassifier

# %%
GCV = GridSearchCV(DecisionTreeClassifier(),parameters,cv = 5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %% [markdown]
# We get params, Now we'll put them into the model

# %%
mod = DecisionTreeClassifier(criterion = 'entropy',max_features = 'sqrt',max_depth = 8,splitter = 'best')

mod.fit(x_train,y_train)
pred = mod.predict(x_test)
print('Accuracy Score of the DT Model:',accuracy_score(y_test,pred)*100)
modCV = cross_val_score(mod,x,y,cv = 5)
print('Cross Validation Score of DT is',modCV.mean()*100)
print('Confusion Matrix:\n',confusion_matrix(y_test,pred))
print('Classification Report:\n',classification_report(y_test,pred))
print('roc_auc_score:',roc_auc_score(y_test,pred)*100)

metrics.plot_roc_curve(mod,x_test,y_test)
plt.show()
# Out:
# Accuracy Score of the DT Model: 82.60533436412834
# Cross Validation Score of DT is 80.953934664696
# Confusion Matrix:
#  [[1077  169]
#  [ 281 1060]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.86      0.83      1246
#            1       0.86      0.79      0.82      1341
#
#     accuracy                           0.83      2587
#    macro avg       0.83      0.83      0.83      2587
# weighted avg       0.83      0.83      0.83      2587
#
# roc_auc_score: 82.741042776108

# %% [markdown]
# By putting the best params into the DecisionTreeClassifier model we get 82.60 accuracy score and 80.95 CV score

# %%
#GridSearchCV Parameteers for RandomForestClassifier
#Adding parameters 
parameters = {'n_estimators':[20,30,40,50,60],
              'criterion':['gini','entropy'],
              'max_depth':[2,3,4,5,6,7],
              'max_features':['auto','sqrt','log2'],
              'min_samples_leaf':[1,2,3,4,5]}

# %% [markdown]
# Parameters for RandomForestClassifier

# %%
#Using GridSearchCV for finding best params
GCV = GridSearchCV(rf,parameters,cv = 5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'n_estimators': 20}

# %% [markdown]
# We get best params

# %%
finalmod = RandomForestClassifier(criterion = 'gini',max_depth =7, max_features = 'sqrt',n_estimators = 20, min_samples_leaf = 2,)

finalmod.fit(x_train,y_train)
pred = finalmod.predict(x_test)
print('Accuracy Score of the RF Model:',accuracy_score(y_test,pred)*100)
finalmodCV = cross_val_score(finalmod,x,y,cv = 5)
print('Cross Validation Score of RF Model is',finalmodCV.mean()*100)
print('Confusion Matrix:\n',confusion_matrix(y_test,pred))
print('Classification Report:\n',classification_report(y_test,pred))
print('roc_auc_score:',roc_auc_score(y_test,pred)*100)

metrics.plot_roc_curve(finalmod,x_test,y_test)
plt.show()
# Out:
# Accuracy Score of the RF Model: 85.65906455353691
# Cross Validation Score of RF Model is 82.92550019496454
# Confusion Matrix:
#  [[1047  199]
#  [ 172 1169]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      1246
#            1       0.85      0.87      0.86      1341
#
#     accuracy                           0.86      2587
#    macro avg       0.86      0.86      0.86      2587
# weighted avg       0.86      0.86      0.86      2587
#
# roc_auc_score: 85.60132169399948

# %% [markdown]
# By putting the best params into the RandomForestClassifier model we get 82.60 accuracy score and 82.92 CV score

# %%
#GridSearchCV Parameteers for LogisticRegression
#Adding parameters 
parameters = {'penalty':['l1', 'l2', 'elasticnet', 'none'],
              'C':[1.0,1.3,1.6,1.8,],
              'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
              'intercept_scaling':[1,2,3,4,5]}

# %% [markdown]
# Parameters for Logistic Regression

# %%
#Using GridSearchCV for finding best params
GCV = GridSearchCV(log_reg,parameters,cv = 5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'C': 1.0, 'intercept_scaling': 1, 'penalty': 'l2', 'solver': 'newton-cg'}

# %% [markdown]
# We get best params

# %%
lrmod = LogisticRegression(penalty = 'l2',C =1.0, solver = 'newton-cg', intercept_scaling = 1,)

lrmod.fit(x_train,y_train)
pred = lrmod.predict(x_test)
print('Accuracy Score of the logistic regression Model:',accuracy_score(y_test,pred)*100)
lrmodCV = cross_val_score(lrmod,x,y,cv = 5)
print('Cross Validation Score of logistic regression Model is',lrmodCV.mean()*100)
print('Confusion Matrix:\n',confusion_matrix(y_test,pred))
print('Classification Report:\n',classification_report(y_test,pred))
print('roc_auc_score:',roc_auc_score(y_test,pred)*100)

metrics.plot_roc_curve(lrmod,x_test,y_test)
plt.show()
# Out:
# Accuracy Score of the logistic regression Model: 79.3196752995748
# Cross Validation Score of logistic regression Model is 77.46429346950497
# Confusion Matrix:
#  [[ 950  296]
#  [ 239 1102]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78      1246
#            1       0.79      0.82      0.80      1341
#
#     accuracy                           0.79      2587
#    macro avg       0.79      0.79      0.79      2587
# weighted avg       0.79      0.79      0.79      2587
#
# roc_auc_score: 79.21073011563927

# %% [markdown]
# By putting the best params into the LogisticRegression model we get 79.31 accuracy score and 77.46 CV score

# %%
#Saving Final Model
import joblib
joblib.dump(finalmod,'Customer Churn Analysis.pkl')
# Out:
# ['Customer Churn Analysis.pkl']

# %% [markdown]
# Saving the final model
